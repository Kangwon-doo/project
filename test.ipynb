# %%
import pandas as pd
import emoji

# %%
coffeeDB = pd.read_csv('mysite/data/coffeeDB.csv')
coffeeDB.shape
# Out:
# (559, 31)

# %%
coffeeDB2 = pd.read_csv('mysite/data/coffeeDB2.csv')
coffeeDB2.shape
# Out:
# (559, 31)

# %%
test = pd.read_csv('Coffeetest.csv')
test.shape
# Out:
# (552, 26)

# %%
coffee_list = list(coffeeDB['id'].unique())
test_list = list(test['CoffeeID'].unique())
print(coffee_list[:5])
print(test_list[:5])

# %%
empty = []
for i in coffee_list:
    if i not in test_list:
        empty.append(i)
print(len(empty))
# Out:
# 7

# %%
coffeeDB[coffeeDB['id'].isin(empty)]
# Out:
#      new_id    id                       이름  로스터리ID  \
# 414     414  3921          아몰렌떼 디카페인 원두 커피      51
# 493     493  4613                  프레쉬 블렌드     110
# 494     494  4614                콜롬비아 디카페인     110
# 555     555  4874                 스트레토 블렌드      45
# 556     556  4876                   알토 블렌드      45
# 557     557  4877                  구스토 블렌드      45
# 558     558  4878  과테말라 디카페인 (마운틴 워터 프로세스)      45
#
#                                                  커피 소개     타입 로스팅 포인트 지속가능성  \
# 414  🥤 카페인 99.9%(0.00mg) 제거 - 믿을수 있는 화이트 세스코에서 검증  ...  싱글오리진   미디엄다크     0
# 493  Tasting note 베리, 복숭아, 카라멜, 시러피 Hebe's ﻿comment...    블렌드  라이트미디엄     0
# 494  Tasting note 밀크초콜릿, 카라멜, 헤이즐넛, 부드러운 산미 Hebe's ...  싱글오리진   미디엄다크     0
# 555  묵직하고 부드러운 바디감, 입안 가득 느껴지는 은은한 단맛. 복합적인 향미가 단맛과...    블렌드   미디엄다크     0
# 556                 스모키하고 다크한 초콜릿과 아몬드 묵직한 바디감을 지닌 블렌드    블렌드      다크     0
# 557  상큼한 과일의 기분 좋은 산미와 화려한 꽃향이 우아하게 느껴지는 뛰어난 풍미를 지닌...    블렌드  라이트미디엄     0
# ...

# %%
test = coffeeDB[coffeeDB['id'].isin(empty)]
test.head(2)
# Out:
#      new_id    id               이름  로스터리ID  \
# 414     414  3921  아몰렌떼 디카페인 원두 커피      51
# 493     493  4613          프레쉬 블렌드     110
#
#                                                  커피 소개     타입 로스팅 포인트 지속가능성  \
# 414  🥤 카페인 99.9%(0.00mg) 제거 - 믿을수 있는 화이트 세스코에서 검증  ...  싱글오리진   미디엄다크     0
# 493  Tasting note 베리, 복숭아, 카라멜, 시러피 Hebe's ﻿comment...    블렌드  라이트미디엄     0
#
#     컵 노트  바디감  ...   원재료 및 함량     제품문의 관련 주소 및 전화번호  price  꽃 과일 허브 달콤함 고소함  \
# 414  NaN    4  ...  커피원두 100%  아몰렌떼 / 070-8843-0526  13000  0  0  0   0   0
# 493  NaN    3  ...  커피원두 100%    헤베커피 010-5295-5742  13000  0  0  0   0   0
#
#     향료 초콜릿
# 414  0   0
# 493  0   0
#
# [2 rows x 31 columns]

# %%
test.to_csv('mysite/data/empty.csv', index=0)
df = pd.read_csv('mysite/data/empty.csv')
df.head(2)
# Out:
#    new_id    id               이름  로스터리ID  \
# 0     414  3921  아몰렌떼 디카페인 원두 커피      51
# 1     493  4613          프레쉬 블렌드     110
#
#                                                커피 소개     타입 로스팅 포인트  지속가능성  \
# 0  🥤 카페인 99.9%(0.00mg) 제거 - 믿을수 있는 화이트 세스코에서 검증  ...  싱글오리진   미디엄다크      0
# 1  Tasting note 베리, 복숭아, 카라멜, 시러피 Hebe's ﻿comment...    블렌드  라이트미디엄      0
#
#    컵 노트  바디감  ...   원재료 및 함량     제품문의 관련 주소 및 전화번호  price  꽃 과일 허브 달콤함 고소함 향료  \
# 0   NaN    4  ...  커피원두 100%  아몰렌떼 / 070-8843-0526  13000  0  0  0   0   0  0
# 1   NaN    3  ...  커피원두 100%    헤베커피 010-5295-5742  13000  0  0  0   0   0  0
#
#   초콜릿
# 0   0
# 1   0
#
# [2 rows x 31 columns]

# %%
df['커피 소개'] = df['커피 소개'].apply(lambda s: emoji.replace_emoji(s, ''))
df.to_csv('mysite/data/empty.csv', index=0)
df = pd.read_csv('mysite/data/empty.csv')
df.head(2)
# Out:
#    new_id    id                       이름  로스터리ID  \
# 0     414  3921          아몰렌떼 디카페인 원두 커피      51
# 1     493  4613                  프레쉬 블렌드     110
# 2     494  4614                콜롬비아 디카페인     110
# 3     555  4874                 스트레토 블렌드      45
# 4     556  4876                   알토 블렌드      45
# 5     557  4877                  구스토 블렌드      45
# 6     558  4878  과테말라 디카페인 (마운틴 워터 프로세스)      45
#
#                                                커피 소개     타입 로스팅 포인트  지속가능성  \
# 0   카페인 99.9%(0.00mg) 제거 - 믿을수 있는 화이트 세스코에서 검증   ...  싱글오리진   미디엄다크      0
# 1  Tasting note 베리, 복숭아, 카라멜, 시러피 Hebe's ﻿comment...    블렌드  라이트미디엄      0
# 2  Tasting note 밀크초콜릿, 카라멜, 헤이즐넛, 부드러운 산미 Hebe's ...  싱글오리진   미디엄다크      0
# 3  묵직하고 부드러운 바디감, 입안 가득 느껴지는 은은한 단맛. 복합적인 향미가 단맛과...    블렌드   미디엄다크      0
# 4                 스모키하고 다크한 초콜릿과 아몬드 묵직한 바디감을 지닌 블렌드    블렌드      다크      0
# 5  상큼한 과일의 기분 좋은 산미와 화려한 꽃향이 우아하게 느껴지는 뛰어난 풍미를 지닌...    블렌드  라이트미디엄      0
# ...

# %%
coffeeDB['커피 소개'] = coffeeDB['커피 소개'].apply(lambda s: emoji.replace_emoji(s, ''))
coffeeDB.to_csv('mysite/data/coffeeDB.csv', index=0)
coffeeDB = pd.read_csv('mysite/data/coffeeDB.csv')
coffeeDB[coffeeDB['id']==3921]
# Out:
#      new_id    id               이름  로스터리ID  \
# 414     414  3921  아몰렌떼 디카페인 원두 커피      51
#
#                                                  커피 소개     타입 로스팅 포인트 지속가능성  \
# 414   카페인 99.9%(0.00mg) 제거 - 믿을수 있는 화이트 세스코에서 검증   ...  싱글오리진   미디엄다크     0
#
#     컵 노트  바디감  ...   원재료 및 함량     제품문의 관련 주소 및 전화번호  price  꽃 과일 허브 달콤함 고소함  \
# 414  NaN    4  ...  커피원두 100%  아몰렌떼 / 070-8843-0526  13000  0  0  0   0   0
#
#     향료 초콜릿
# 414  0   0
#
# [1 rows x 31 columns]

# %%
coffeeDB2['커피 소개'] = coffeeDB2['커피 소개'].apply(lambda s: emoji.replace_emoji(s, ''))
coffeeDB2.to_csv('mysite/data/coffeeDB2.csv', index=0)
coffeeDB2 = pd.read_csv('mysite/data/coffeeDB2.csv')
coffeeDB2[coffeeDB2['id']==3921]
# Out:
#      new_id    id               이름  로스터리ID  \
# 414     414  3921  아몰렌떼 디카페인 원두 커피      51
#
#                                                  커피 소개     타입 로스팅 포인트 지속가능성  \
# 414   카페인 99.9%(0.00mg) 제거 - 믿을수 있는 화이트 세스코에서 검증   ...  싱글오리진   미디엄다크     0
#
#     컵 노트  바디감  ...   원재료 및 함량     제품문의 관련 주소 및 전화번호  price  꽃 과일 허브 달콤함 고소함  \
# 414  NaN    4  ...  커피원두 100%  아몰렌떼 / 070-8843-0526  13000  0  0  0   0   0
#
#     향료 초콜릿
# 414  0   0
#
# [1 rows x 31 columns]

# %% [markdown]
# ***
# ***

# %%
test = pd.read_csv('Coffeetest.csv')
test.shape
# Out:
# (555, 26)

# %%
coffee_list = list(coffeeDB['id'].unique())
test_list = list(test['CoffeeID'].unique())

# %%
empty = []
for i in coffee_list:
    if i not in test_list:
        empty.append(i)
print(len(empty))
# Out:
# 4

# %%
test = coffeeDB[coffeeDB['id'].isin(empty)]
test.to_csv('mysite/data/empty.csv', index=0)
df = pd.read_csv('mysite/data/empty.csv')
df.head(2)
# Out:
#    new_id    id        이름  로스터리ID  \
# 0     555  4874  스트레토 블렌드      45
# 1     556  4876    알토 블렌드      45
#
#                                                커피 소개   타입 로스팅 포인트  지속가능성  \
# 0  묵직하고 부드러운 바디감, 입안 가득 느껴지는 은은한 단맛. 복합적인 향미가 단맛과...  블렌드   미디엄다크      0
# 1                 스모키하고 다크한 초콜릿과 아몬드 묵직한 바디감을 지닌 블렌드  블렌드      다크      0
#
#    컵 노트  바디감  ...   원재료 및 함량       제품문의 관련 주소 및 전화번호  price  꽃 과일 허브 달콤함 고소함  \
# 0   NaN    4  ...  커피원두 100%  스트레토 커피팩토리 01086790553  15000  0  0  0   0   0
# 1   NaN    5  ...  커피원두 100%  스트레토 커피팩토리 01086790553  13000  0  0  0   0   0
#
#   향료 초콜릿
# 0  0   0
# 1  0   0
#
# [2 rows x 31 columns]

# %%
df['로스터리ID']
# Out:
# 0    45
# 1    45
# 2    45
# 3    45
# Name: 로스터리ID, dtype: int64

# %%
coffeeDB[coffeeDB['로스터리ID']==45]
# Out:
#      new_id    id                       이름  로스터리ID  \
# 555     555  4874                 스트레토 블렌드      45
# 556     556  4876                   알토 블렌드      45
# 557     557  4877                  구스토 블렌드      45
# 558     558  4878  과테말라 디카페인 (마운틴 워터 프로세스)      45
#
#                                                  커피 소개     타입 로스팅 포인트 지속가능성  \
# 555  묵직하고 부드러운 바디감, 입안 가득 느껴지는 은은한 단맛. 복합적인 향미가 단맛과...    블렌드   미디엄다크     0
# 556                 스모키하고 다크한 초콜릿과 아몬드 묵직한 바디감을 지닌 블렌드    블렌드      다크     0
# 557  상큼한 과일의 기분 좋은 산미와 화려한 꽃향이 우아하게 느껴지는 뛰어난 풍미를 지닌...    블렌드  라이트미디엄     0
# 558  군고구마의 향미와 오렌지의 상큼함이 함께 느껴지는 커피로 굉장히 마일드한 촉감을 지...  싱글오리진   미디엄다크     0
#
#     컵 노트  바디감  ...   원재료 및 함량       제품문의 관련 주소 및 전화번호  price  꽃 과일 허브 달콤함 고소함  \
# 555  NaN    4  ...  커피원두 100%  스트레토 커피팩토리 01086790553  15000  0  0  0   0   0
# 556  NaN    5  ...  커피원두 100%  스트레토 커피팩토리 01086790553  13000  0  0  0   0   0
# 557  NaN    2  ...  커피원두 100%  스트레토 커피팩토리 01086790553  13000  0  0  0   0   0
# ...

# %%
Rst = pd.read_csv('mysite/data/roasteryDB.csv')
Rst.head(2)
# Out:
#    로스터리ID   로스터리                 로스터리 주소  \
# 0      57  언더프레셔   서울 강남구 영동대로106길 37 1층
# 1      67   운조커피  경기도 화성시 동탄지성로 306번길 68
#
#                                              로스터리 소개      phone_numbers
# 0  “일상 속 특별한 휴식” 커피를 추출하는 기본 원리인 물줄기의 압력(Pressure...      ['1599-2681']
# 1  커피가 나에게 준 커다란 변화를 모두와 나누고 싶습니다. 나의 이름이 붙은 커피를 ...  ['010-4535-8819']

# %%
Rst[Rst['로스터리']=='스트레토 커피팩토리']
# Out:
#     로스터리ID        로스터리                  로스터리 주소  \
# 84      45  스트레토 커피팩토리  경기도 파주시 문산읍 사목로 69번지 3동
#
#                                               로스터리 소개    phone_numbers
# 84  스트레토는 맛있는 커피 원두만 납품하지 않습니다. 스트레토는 맛있는 커피 한잔을 납...  ['01086790553']

# %%
string = Rst[Rst['로스터리']=='스트레토 커피팩토리']['로스터리 소개'].values[0]

# %%
string
# Out:
# '스트레토는 맛있는 커피 원두만 납품하지 않습니다. 스트레토는 맛있는 커피 한잔을 납품합니다. 스트레토 원두가 맛있는 커피 한 잔으로 완성될 수 있도록 언제 어디서나 가장 맛있게 드실 수 있도록 스트레토가 모든 순간에 함께하겠습니다. 𝘀𝘁𝗿𝗲𝘁𝘁𝗼 𝘀𝘁𝗮𝘆𝘀 𝘄𝗶𝘁𝗵𝗶𝗻 𝘆𝗼𝘂. [𝘀𝘁𝗿𝗲𝘁𝘁𝗼 𝘀𝗽𝗶𝗿𝗶𝘁] 𝗰𝗼𝗻𝘀𝗶𝘀𝘁𝗲𝗻𝗰𝘆 : 스트레토는 언제 어디서나 일관된 맛을 구현하는 것을 중요하게 여깁니다. 𝗶𝗻𝘁𝗲𝗻𝘀𝗶𝘁𝘆 : 스트레토는 강렬한 첫인상 그리고 오랜 여운을 남기는 짙은 커피향과 더불어 인상 깊고 만족도 높은 제품과 서비스를 통해 진한 기억을 남기는 브랜드가 되고자 합니다. 𝗿𝗲𝘀𝗽𝗼𝗻𝘀𝗶𝗯𝗶𝗹𝗶𝘁𝘆 : 스트레토는 커피원두가 커피 한 잔으로 완성되는 모든 과정에서 만족스러운 서비스를 제공하기 위해 ‘맛있는 커피 한 잔’에 대한 책임감을 갖고 고객의 요청에 귀 기울이며 진심을 담아 케어합니다.'

# %%
import re

english_text = re.findall(r'[A-Za-z\s]+', string)
print(english_text)
# Out:
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']

# %%
from langdetect import detect
for i in string:
    if detect(i) != 'ko':
        print(i)
# Out:
# ---------------------------------------------------------------------------
# LangDetectException                       Traceback (most recent call last)
# c:\Users\Playdata\Documents\project_coffee\test.ipynb 셀 25 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/Playdata/Documents/project_coffee/test.ipynb#X65sZmlsZQ%3D%3D?line=0'>1</a> from langdetect import detect
#       <a href='vscode-notebook-cell:/c%3A/Users/Playdata/Documents/project_coffee/test.ipynb#X65sZmlsZQ%3D%3D?line=1'>2</a> for i in string:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Playdata/Documents/project_coffee/test.ipynb#X65sZmlsZQ%3D%3D?line=2'>3</a>     if detect(i) != 'ko':
#       <a href='vscode-notebook-cell:/c%3A/Users/Playdata/Documents/project_coffee/test.ipynb#X65sZmlsZQ%3D%3D?line=3'>4</a>         print(i)
#
# File c:\venvs\coffee\lib\site-packages\langdetect\detector_factory.py:130, in detect(text)
#     128 detector = _factory.create()
#     129 detector.append(text)
# ...

# %%
comment = "스트레토는 맛있는 커피 원두만 납품하지 않습니다. 스트레토는 맛있는 커피 한잔을 납품합니다. 스트레토 원두가 맛있는 커피 한 잔으로 완성될 수 있도록 언제 어디서나 가장 맛있게 드실 수 있도록 스트레토가 모든 순간에 함께하겠습니다. stretto stays within you. [stretto spirit] consistency : 스트레토는 언제 어디서나 일관된 맛을 구현하는 것을 중요하게 여깁니다. intensity : 스트레토는 강렬한 첫인상 그리고 오랜 여운을 남기는 짙은 커피향과 더불어 인상 깊고 만족도 높은 제품과 서비스를 통해 진한 기억을 남기는 브랜드가 되고자 합니다. responsobility : 스트레토는 커피원두가 커피 한 잔으로 완성되는 모든 과정에서 만족스러운 서비스를 제공하기 위해 ‘맛있는 커피 한 잔’에 대한 책임감을 갖고 고객의 요청에 귀 기울이며 진심을 담아 케어합니다."

# %%
english_text = re.findall(r'[A-Za-z\s]+', comment)
print(english_text)
# Out:
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' stretto stays within you', ' ', 'stretto spirit', ' consistency ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' intensity ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' responsobility ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']

# %%
Rst.loc[Rst['로스터리ID']==45, '로스터리 소개'] = comment

# %%
string = Rst[Rst['로스터리']=='스트레토 커피팩토리']['로스터리 소개'].values[0]

# %%
english_text = re.findall(r'[A-Za-z\s]+', string)
print(english_text)
# Out:
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' stretto stays within you', ' ', 'stretto spirit', ' consistency ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' intensity ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' responsobility ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']

# %%
string
# Out:
# '스트레토는 맛있는 커피 원두만 납품하지 않습니다. 스트레토는 맛있는 커피 한잔을 납품합니다. 스트레토 원두가 맛있는 커피 한 잔으로 완성될 수 있도록 언제 어디서나 가장 맛있게 드실 수 있도록 스트레토가 모든 순간에 함께하겠습니다. stretto stays within you. [stretto spirit] consistency : 스트레토는 언제 어디서나 일관된 맛을 구현하는 것을 중요하게 여깁니다. intensity : 스트레토는 강렬한 첫인상 그리고 오랜 여운을 남기는 짙은 커피향과 더불어 인상 깊고 만족도 높은 제품과 서비스를 통해 진한 기억을 남기는 브랜드가 되고자 합니다. responsobility : 스트레토는 커피원두가 커피 한 잔으로 완성되는 모든 과정에서 만족스러운 서비스를 제공하기 위해 ‘맛있는 커피 한 잔’에 대한 책임감을 갖고 고객의 요청에 귀 기울이며 진심을 담아 케어합니다.'

# %%
Rst.to_csv('mysite/data/roasteryDB.csv', index=0)
Rst = pd.read_csv('mysite/data/roasteryDB.csv')
Rst.head(2)
# Out:
#    로스터리ID   로스터리                 로스터리 주소  \
# 0      57  언더프레셔   서울 강남구 영동대로106길 37 1층
# 1      67   운조커피  경기도 화성시 동탄지성로 306번길 68
#
#                                              로스터리 소개      phone_numbers
# 0  “일상 속 특별한 휴식” 커피를 추출하는 기본 원리인 물줄기의 압력(Pressure...      ['1599-2681']
# 1  커피가 나에게 준 커다란 변화를 모두와 나누고 싶습니다. 나의 이름이 붙은 커피를 ...  ['010-4535-8819']

# %% [markdown]
# ***

# %%
coffeeids = [2,3,2]
orderids = [1,1,2]

coffeeorderpairs = []
Reviewinfo = Reviews.objects.filter(user=userid)

coffeeorderpairs = [(i.Coffee_id, i.Order_id) for i in Reviews.objects.filter(user=userid)]

# %%
'pair_exists': (item.product.CoffeeID, item.OrderID_id) in coffeeid_orderid_pairs

# %%
pair_exists_list = [True, False, True, True]
orderitems = [1,2,3,4]
items_pair_exists = zip(orderitems, pair_exists_list)
items_pair_exists

# %%
coffeeid_orderid_pairs = [(2, '47ce61a4-c1a7-46c0-ae39-c5336216f301'), (2, 'eee971c5-aab7-415e-bb5f-58f268e46062'), (3, '47ce61a4-c1a7-46c0-ae39-c5336216f301')]
temp = coffeeid_orderid_pairs[0]
coffeeid_orderid_pairs[0]
# Out:
# (2, '47ce61a4-c1a7-46c0-ae39-c5336216f301')

# %%
temp[0]
# Out:
# 2

# %%
res = list(zip(orderitems, pair_exists_list))
res
# Out:
# [(1, True), (2, False), (3, True), (4, True)]

# %%
dictionary = {'itemid1' : 'str1', 'itemid2':'str2'}
dictionary.get('itemid1')
# Out:
# 'str1'

# %%
import pandas as pd
df = pd.read_csv('userinfo.csv')

# %%
df.head()
# Out:
#    id                email  Caffeine  CoffeeType      CupNoteCategories  Body  \
# 0   3   hwhj1214@naver.com         0           1         ['초콜릿', '고소함']     4
# 1   4   syjflora@gmail.com         1           0  ['초콜릿', '달콤함', '고소함']     3
# 2   5   aiwithsj@gmail.com         0           0                ['고소함']     4
# 3   6  katherine@gmail.com         0           0                ['고소함']     5
# 4   7   seunghyun@test.com         0           1         ['달콤함', '고소함']     3
#
#    Sourness  Sweetness  Bitterness
# 0         1          4           2
# 1         3          3           3
# 2         2          3           3
# 3         1          1           4
# 4         1          5           2

# %%
new_keys = ['꽃', '과일', '달콤함', '허브', '고소함', '향료', '초콜릿']
for key in new_keys:
    df.loc[:, key] = 0

# %%
df.head()
# Out:
#    id                email  Caffeine  CoffeeType      CupNoteCategories  Body  \
# 0   3   hwhj1214@naver.com         0           1         ['초콜릿', '고소함']     4
# 1   4   syjflora@gmail.com         1           0  ['초콜릿', '달콤함', '고소함']     3
# 2   5   aiwithsj@gmail.com         0           0                ['고소함']     4
# 3   6  katherine@gmail.com         0           0                ['고소함']     5
# 4   7   seunghyun@test.com         0           1         ['달콤함', '고소함']     3
#
#    Sourness  Sweetness  Bitterness  꽃  과일  달콤함  허브  고소함  향료  초콜릿
# 0         1          4           2  0   0    0   0    0   0    0
# 1         3          3           3  0   0    0   0    0   0    0
# 2         2          3           3  0   0    0   0    0   0    0
# 3         1          1           4  0   0    0   0    0   0    0
# 4         1          5           2  0   0    0   0    0   0    0

# %%
test_row = df[df.index == 0]
test_row
# Out:
#    id               email  Caffeine  CoffeeType CupNoteCategories  Body  \
# 0   3  hwhj1214@naver.com         0           1    ['초콜릿', '고소함']     4
#
#    Sourness  Sweetness  Bitterness  꽃  과일  달콤함  허브  고소함  향료  초콜릿
# 0         1          4           2  0   0    0   0    0   0    0

# %%
new_keys = ['꽃', '과일', '달콤함', '허브', '고소함', '향료', '초콜릿']
for key in new_keys:
    test_row.loc[:, key] = 0

# %%
test_row
# Out:
#    id               email  Caffeine  CoffeeType CupNoteCategories  Body  \
# 0   3  hwhj1214@naver.com         0           1    ['초콜릿', '고소함']     4
#
#    Sourness  Sweetness  Bitterness  꽃  과일  달콤함  허브  고소함  향료  초콜릿
# 0         1          4           2  0   0    0   0    0   0    0
