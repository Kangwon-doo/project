# %%
mock = {'email': 'hwhj1214@naver.com', '137': '5', '292': '4', '1063': '3', '1341': '5', '3013': '3', '3029': '5', '3041': '3', '3935': '2', '4333': '1', '4736': '5'}

# %% [markdown]
# test_Reviews.objects.create(
#                blog = blog,
#                name = data.name
#                email = data.email
#                text = data.text
#                date = timezone.now()
#            )
#
# CoffeeID = models.ForeignKey(Coffee, on_delete=models.CASCADE)
# ######## 사용자 입력값 ########
# email = models.EmailField(max_length=40)  # 이메일
# Caffeine = models.CharField(max_length=1)  # 디카페인/카페인
# CoffeeType = models.TextField()  # 타입
# CupNoteCategories = models.PositiveSmallIntegerField()  # 선호 컵 노트 카테고리
# Body = models.CharField(max_length=1)  # 바디감
# Sourness = models.CharField(max_length=1)  # 신맛
# Sweetness = models.CharField(max_length=1)  # 단맛
# Bitterness = models.CharField(max_length=1)  # 쓴맛
# Stars = models.CharField(max_length=1, default=0) # 별점. 1~5점. 0점은 아직 리뷰를 남기지 않은 커피
#
# created_date = models.DateTimeField()

# %%
# test_Reviews.objects.create(
#                email = email
#                coffee_id = 
#                stars = 
#                created_date = timezone.now()
#            )

# %%
score = dict(list(mock.items())[-10:])
keys = list(score.keys())
values = list(score.values())

# %%
score
# Out:
# {'137': '5',
#  '292': '4',
#  '1063': '3',
#  '1341': '5',
#  '3013': '3',
#  '3029': '5',
#  '3041': '3',
#  '3935': '2',
#  '4333': '1',
#  '4736': '5'}

# %%
print(keys)
print(values)
# Out:
# ['137', '292', '1063', '1341', '3013', '3029', '3041', '3935', '4333', '4736']
# ['5', '4', '3', '5', '3', '5', '3', '2', '1', '5']

# %%
import pandas as pd

# %%
coffeeDB = pd.read_csv('mysite/data/coffeeDB2.csv')
coffeeDB=coffeeDB.drop(columns=['Unnamed: 0'])
coffeeDB.head(2)
# Out:
#      id            이름  로스터리ID  \
# 0    43         데일리스윗      57
# 1  3896  브라질 세라도 디카페인      67
#
#                                                커피 소개    타입 로스팅 포인트 지속가능성  \
# 0  중남미 블렌딩으로 깊이 있는 단맛과 초콜렛티함이 조화롭게 어우러진 하우스 블렌드 입...   블렌드   미디엄다크     0
# 1  땅콩의 고소함과 코코아 파우더의 쌉싸름함 진득한 단맛과 클래식한 커피향  중강배전으...  디카페인   미디엄다크     0
#
#                   컵 노트  바디감  신맛  ...               나라    식품의 유형  \
# 0  ['토피', '맥아', '흑설탕']    4   2  ...  ['브라질', '과테말라']  커피(볶은커피)
# 1                  NaN    4   2  ...          ['세라도']        커피
#
#                       제조원 및 소재지         유통기한        제조일자         내용량  \
# 0  (주)핸디엄, 경기도 여주시 세종대왕면 상동길 68  제조일로부터 12개월      상단 표기일  140g / 1kg
# 1        경기도 화성시 동탄지성로 306번길 68    제조일로부터 1년  주문 확인 후 제조    500g 1kg
#
#                                           보관 방법  \
# 0  직사광선을 피하고 온도, 습도가 낮으며 통풍이 잘 되는 곳에 보관하여 주십시오.
# 1       직사광선을 피하고 온도, 습도가 낮으며 통풍이 잘 되는 곳에 밀폐 보관
#
#                           원재료 및 함량   제품문의 관련 주소 및 전화번호  price
# 0  커피원두 100% (브라질산 60%, 과테말라산 40%)  핸디엄 고객센터 1599-2681  11800
# 1                        커피원두 100%  운조커피 010-4535-8819  13000
#
# [2 rows x 23 columns]

# %%
coffeeDB = coffeeDB.sort_values(by=['id'])
coffeeDB.head(3)
# Out:
#      id   이름  로스터리ID                                              커피 소개   타입  \
# 534   2  나탈리      60  잘 익은 딸기를 베어 문듯한 단맛과 적당한 산미의 조화를 이루는 와인의 풍미를 느낄...  블렌드
# 332   3   콜린      60  잘 익은 체리의 농후한 단맛과 고소한 아몬드 캐러멜이 입안 가득 남는 끝 맛을 느낄...  블렌드
# 516   5  매뉴얼       5  아메리카노, 라떼 모두 잘 어울리는 블렌딩입니다. 부드럽고 은은하게 올라오는 산미와...  블렌드
#
#     로스팅 포인트 지속가능성                     컵 노트  바디감  신맛  ...  \
# 534     미디엄  공정무역  ['딸기', '와인', '화이트 초콜릿']    2   3  ...
# 332   미디엄다크  공정무역  ['다크 초콜릿', '체리', '아몬드']    4   2  ...
# 516   미디엄다크     0                      NaN    4   2  ...
#
#                                        나라  식품의 유형  \
# 534  ['파푸아뉴기니 바로이디아 콜브란', '브라질', '코스타리카']   원두 커피
# 332               ['인도', '콜롬비아', '코스타리카']   원두 커피
# 516        ['브라질', '에티오피아', '인도', '과테말라']   볶은 커피
#
#                                     제조원 및 소재지                       유통기한  \
# 534  영앤도터스, 서울 마포구 마포대로 156 공덕 프루지오시티 1층 107호                  제조일로부터 1년
# 332  영앤도터스, 서울 마포구 마포대로 156 공덕 프루지오시티 1층 107호  제조일로부터 1년(권장기한 제조일로부터 1달)
# 516                                     그럼블커피                 제조일로부터 6개월
#
#           제조일자         내용량                          보관 방법  \
# 534  제조일 별도 표기  200g / 1kg  직사광선을 피하고 밀봉하여 건조하고 서늘한 곳에 보관
# 332  제조일 별도 표기  200g / 1kg  직사광선을 피하고 밀봉하여 건조하고 서늘한 곳에 보관
# 516  제조일 별도 표기  200g / 1kg          직사광선을 피하고 서늘한 곳에 밀폐보관
#
#                                     원재료 및 함량      제품문의 관련 주소 및 전화번호  price
# 534  원두 커피(엘살바도르 30%, 파푸아뉴기니 40%, 코스타리카 30%)  코케 고객센터 070-4647-1868  16000
# 332       원두 커피(코스타리카 30%, 콜롬비아 40%, 인도 30%)  코케 고객센터 070-4647-1868  16000
# 516      커피원두 100% (브라질, 과테말라, 인도네시아, 에디오피아)  코케 고객센터 070-4647-1868  11000
#
# [3 rows x 23 columns]

# %%
coffeeDB.reset_index(drop=False)
coffeeDB = coffeeDB.reset_index(drop=True)

# %%
coffeeDB.reset_index(inplace=True)
coffeeDB.head(2)
# Out:
#    index  id   이름  로스터리ID                                              커피 소개  \
# 0      0   2  나탈리      60  잘 익은 딸기를 베어 문듯한 단맛과 적당한 산미의 조화를 이루는 와인의 풍미를 느낄...
# 1      1   3   콜린      60  잘 익은 체리의 농후한 단맛과 고소한 아몬드 캐러멜이 입안 가득 남는 끝 맛을 느낄...
#
#     타입 로스팅 포인트 지속가능성                     컵 노트  바디감  ...  \
# 0  블렌드     미디엄  공정무역  ['딸기', '와인', '화이트 초콜릿']    2  ...
# 1  블렌드   미디엄다크  공정무역  ['다크 초콜릿', '체리', '아몬드']    4  ...
#
#                                      나라  식품의 유형  \
# 0  ['파푸아뉴기니 바로이디아 콜브란', '브라질', '코스타리카']   원두 커피
# 1               ['인도', '콜롬비아', '코스타리카']   원두 커피
#
#                                   제조원 및 소재지                       유통기한  \
# 0  영앤도터스, 서울 마포구 마포대로 156 공덕 프루지오시티 1층 107호                  제조일로부터 1년
# 1  영앤도터스, 서울 마포구 마포대로 156 공덕 프루지오시티 1층 107호  제조일로부터 1년(권장기한 제조일로부터 1달)
#
#         제조일자         내용량                          보관 방법  \
# 0  제조일 별도 표기  200g / 1kg  직사광선을 피하고 밀봉하여 건조하고 서늘한 곳에 보관
# 1  제조일 별도 표기  200g / 1kg  직사광선을 피하고 밀봉하여 건조하고 서늘한 곳에 보관
#
#                                   원재료 및 함량      제품문의 관련 주소 및 전화번호  price
# 0  원두 커피(엘살바도르 30%, 파푸아뉴기니 40%, 코스타리카 30%)  코케 고객센터 070-4647-1868  16000
# 1       원두 커피(코스타리카 30%, 콜롬비아 40%, 인도 30%)  코케 고객센터 070-4647-1868  16000
#
# [2 rows x 24 columns]

# %%
coffeeDB = coffeeDB.rename(columns={'index':'new_id'})
coffeeDB.head(2)
# Out:
#    new_id  id   이름  로스터리ID                                              커피 소개  \
# 0       0   2  나탈리      60  잘 익은 딸기를 베어 문듯한 단맛과 적당한 산미의 조화를 이루는 와인의 풍미를 느낄...
# 1       1   3   콜린      60  잘 익은 체리의 농후한 단맛과 고소한 아몬드 캐러멜이 입안 가득 남는 끝 맛을 느낄...
#
#     타입 로스팅 포인트 지속가능성                     컵 노트  바디감  ...  \
# 0  블렌드     미디엄  공정무역  ['딸기', '와인', '화이트 초콜릿']    2  ...
# 1  블렌드   미디엄다크  공정무역  ['다크 초콜릿', '체리', '아몬드']    4  ...
#
#                                      나라  식품의 유형  \
# 0  ['파푸아뉴기니 바로이디아 콜브란', '브라질', '코스타리카']   원두 커피
# 1               ['인도', '콜롬비아', '코스타리카']   원두 커피
#
#                                   제조원 및 소재지                       유통기한  \
# 0  영앤도터스, 서울 마포구 마포대로 156 공덕 프루지오시티 1층 107호                  제조일로부터 1년
# 1  영앤도터스, 서울 마포구 마포대로 156 공덕 프루지오시티 1층 107호  제조일로부터 1년(권장기한 제조일로부터 1달)
#
#         제조일자         내용량                          보관 방법  \
# 0  제조일 별도 표기  200g / 1kg  직사광선을 피하고 밀봉하여 건조하고 서늘한 곳에 보관
# 1  제조일 별도 표기  200g / 1kg  직사광선을 피하고 밀봉하여 건조하고 서늘한 곳에 보관
#
#                                   원재료 및 함량      제품문의 관련 주소 및 전화번호  price
# 0  원두 커피(엘살바도르 30%, 파푸아뉴기니 40%, 코스타리카 30%)  코케 고객센터 070-4647-1868  16000
# 1       원두 커피(코스타리카 30%, 콜롬비아 40%, 인도 30%)  코케 고객센터 070-4647-1868  16000
#
# [2 rows x 24 columns]

# %%
coffeeDB.to_csv('mysite/data/coffeeDB2.csv')
