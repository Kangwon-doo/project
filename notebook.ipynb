# %%
import pandas as pd

# %%
roastery = pd.read_csv('roastery.csv').iloc[:,1:]
roastery.head()
# Out:
#      id                   name     roastery  \
# 0    43                  데일리스윗        언더프레셔
# 1  3896           브라질 세라도 디카페인         운조커피
# 2  3458  에티오피아 예가체프 아리차 g1 내추럴    제이엠디커피팩토리
# 3    22      1st WAVE : Supply  뉴웨이브 커피로스터스
# 4   180           에티오피아 리무 볼렌소     베르크 로스터스
#
#                                                 info  \
# 0  “일상 속 특별한 휴식”\r\n커피를 추출하는 기본 원리인 물줄기의 압력(Press...
# 1  커피가 나에게 준 커다란 변화를 모두와 나누고 싶습니다.\r\n나의 이름이 붙은 커...
# 2  “JMD만의 명품 원두로 그 이상의 무한함을 창조하고자 합니다.”\r\n커피는 이제...
# 3  뉴웨이브 커피로스터스는 확고한 커피의 철학으로 우리만의 스타일로 많은 커피를 전달하...
# 4  부산에 위치한 스몰배치 스페셜티 커피 로스터리이자, 서로 다른 경험과 개성을 가진 ...
#
#                                           address  \
# 0                           서울 강남구 영동대로106길 37 1층
# 1                          경기도 화성시 동탄지성로 306번길 68
# 2  경기 고양시 일산동구 장대길 75-53 나동 1층 JMD Coffee Factory
# 3                           서울특별시 양천구 오목로56길 2,1층
# 4                          부산 부산진구 전포동 356-6 지하1층
#
#                                                  img
# ...

# %%
roastery.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        559 non-null    int64
#  1   name      559 non-null    object
#  2   roastery  559 non-null    object
#  3   info      559 non-null    object
#  4   address   550 non-null    object
#  5   img       559 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 26.3+ KB

# %%
features = pd.read_csv('feaures_fin.csv')
features.head()
# Out:
#      ID          coffee_name    타입 로스팅 포인트 지속가능성                컵 노트  바디감  신맛  \
# 0  1084  에티오피아 G2 시다모 SW 디카프  디카페인     미디엄   NaN  ['오렌지', ' 다크 초콜릿']    2   3
# 1  4699              마일드 블렌딩   블렌드   미디엄다크   NaN                 NaN    3   2
# 2  1727           Blend Dark   블렌드      다크   NaN                 NaN    4   1
# 3  3072             샹젤리제 블렌딩   블렌드  라이트미디엄   NaN                 NaN    2   4
# 4  3217         Hammock (해먹)   블렌드     미디엄   NaN                 NaN    4   1
#
#    단맛  쓴맛
# 0   3   2
# 1   3   3
# 2   3   5
# 3   5   2
# 4   4   2

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           559 non-null    int64
#  1   coffee_name  559 non-null    object
#  2   타입           559 non-null    object
#  3   로스팅 포인트      559 non-null    object
#  4   지속가능성        113 non-null    object
#  5   컵 노트         178 non-null    object
#  6   바디감          559 non-null    int64
#  7   신맛           559 non-null    int64
#  8   단맛           559 non-null    int64
#  9   쓴맛           559 non-null    int64
# dtypes: int64(5), object(5)
# memory usage: 43.8+ KB

# %%
info = pd.read_csv('Required_information_preprocessed.csv')
info.head()
# Out:
#               이름    식품의 유형                     제조원 및 소재지         유통기한  \
# 0          데일리스윗  커피(볶은커피)  (주)핸디엄, 경기도 여주시 세종대왕면 상동길 68  제조일로부터 12개월
# 1        브라운렄블렌드        커피         서울 강북구 한천로139가길 15 1층    제조일로부터 1년
# 2     오렌지 슈가 블렌드        커피       인천시 부평구 부평대로 337, 1031호    제조일로부터 1년
# 3      블렌드 슈퍼 노멀        커피   서울특별시 서대문구 연희로 109, 2층 프로토콜    제조일로부터 1년
# 4  과테말라 안티구아 SHB        커피      충청남도 논산시 연산면 황룡재로 65, 2층    제조일로부터 1년
#
#                제조일자         내용량                                         보관 방법  \
# 0            상단 표기일  140g / 1kg  직사광선을 피하고 온도, 습도가 낮으며 통풍이 잘 되는 곳에 보관하여 주십시오.
# 1        주문 확인 후 제조         1kg       직사광선을 피하고 온도, 습도가 낮으며 통풍이 잘 되는 곳에 밀폐 보관
# 2        주문 확인 후 제조         1kg       직사광선을 피하고 온도, 습도가 낮으며 통풍이 잘 되는 곳에 밀폐 보관
# 3  제조일 별도 표기(제품 뒷면)  200g / 1kg                 직사광선을 피하고 밀봉하여 건조하고 서늘한 곳에 보관
# 4        주문 확인 후 제조         1kg       직사광선을 피하고 온도, 습도가 낮으며 통풍이 잘 되는 곳에 밀폐 보관
#
#                           원재료 및 함량      제품문의 관련 주소 및 전화번호    ID
# ...

# %%
info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   이름                 559 non-null    object
#  1   식품의 유형             554 non-null    object
#  2   제조원 및 소재지          557 non-null    object
#  3   유통기한               557 non-null    object
#  4   제조일자               559 non-null    object
#  5   내용량                559 non-null    object
#  6   보관 방법              545 non-null    object
#  7   원재료 및 함량           559 non-null    object
#  8   제품문의 관련 주소 및 전화번호  559 non-null    object
#  9   ID                 559 non-null    int64
# dtypes: int64(1), object(9)
# memory usage: 43.8+ KB

# %%
coffee = pd.read_csv('remove_string.csv')
coffee.head()
# Out:
#      id          name                                       introduction  \
# 0  4305  클래식 블렌드 1996  자칫 산미의 표현이 부담스러울 수 있는 약볶음 원두의 특징을 고려하여 서로 간의 조...
# 1  3503            D1  낮은 산미와 묵직한 바디감, 좋은 밸런스를 갖춘 블렌드입니다.\n매일 마셔도 부담없...
# 2  1474     다크초콜릿 블렌드   다크로스팅 특유의 진한 느낌과 쌉싸름함이 느껴지지만 쓰지않고 깨끗한 단맛이 특징입니다.
# 3  3198   다크그린 블렌딩 커피  - 풍부한 밸런스에 진한 농도를 더한 커피\n- 산미는 줄이고 구수한 후미를 강조한 커피
# 4  3028       브라운렄블렌드  초콜릿의 향미와 캐러멜 같은 질감의 밸런스가 좋은 커피입니다.\n누구나 부담 없이 ...
#
#                   country
# 0  에티오피아, 브라질, 콜롬비아, 과테말라
# 1     브라질, 과테말라, 콜롬비아, 케냐
# 2           브라질, 콜롬비아, 인도
# 3  브라질, 콜롬비아, 과테말라, 에티오피아
# 4           콜롬비아, 브라질, 인도

# %%
coffee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            559 non-null    int64
#  1   name          559 non-null    object
#  2   introduction  559 non-null    object
#  3   country       543 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 17.6+ KB

# %%
df = pd.merge(roastery, features, left_on='id', right_on='ID').merge(coffee,on='id').merge(info,on='ID')
df.head()
# Out:
#      id                 name_x     roastery  \
# 0    43                  데일리스윗        언더프레셔
# 1  3896           브라질 세라도 디카페인         운조커피
# 2  3458  에티오피아 예가체프 아리차 g1 내추럴    제이엠디커피팩토리
# 3    22      1st WAVE : Supply  뉴웨이브 커피로스터스
# 4   180           에티오피아 리무 볼렌소     베르크 로스터스
#
#                                                 info  \
# 0  “일상 속 특별한 휴식”\r\n커피를 추출하는 기본 원리인 물줄기의 압력(Press...
# 1  커피가 나에게 준 커다란 변화를 모두와 나누고 싶습니다.\r\n나의 이름이 붙은 커...
# 2  “JMD만의 명품 원두로 그 이상의 무한함을 창조하고자 합니다.”\r\n커피는 이제...
# 3  뉴웨이브 커피로스터스는 확고한 커피의 철학으로 우리만의 스타일로 많은 커피를 전달하...
# 4  부산에 위치한 스몰배치 스페셜티 커피 로스터리이자, 서로 다른 경험과 개성을 가진 ...
#
#                                           address  \
# 0                           서울 강남구 영동대로106길 37 1층
# 1                          경기도 화성시 동탄지성로 306번길 68
# 2  경기 고양시 일산동구 장대길 75-53 나동 1층 JMD Coffee Factory
# 3                           서울특별시 양천구 오목로56길 2,1층
# 4                          부산 부산진구 전포동 356-6 지하1층
#
#                                                  img    ID  \
# ...

# %%
columns = ['id',
 'name_x',
 'roastery',
 '타입',
 '로스팅 포인트',
 '지속가능성',
 '컵 노트',
 '바디감',
 '신맛',
 '단맛',
 '쓴맛',
 'introduction',
 'country',
 'info',
 'address',
 '이름',
 '식품의 유형',
 '제조원 및 소재지',
 '유통기한',
 '제조일자',
 '내용량',
 '보관 방법',
 '원재료 및 함량',
 '제품문의 관련 주소 및 전화번호']

# %%
df = df.reindex(columns=columns)
df.head()
# Out:
#      id                 name_x     roastery     타입 로스팅 포인트 지속가능성  \
# 0    43                  데일리스윗        언더프레셔    블렌드   미디엄다크   NaN
# 1  3896           브라질 세라도 디카페인         운조커피   디카페인   미디엄다크   NaN
# 2  3458  에티오피아 예가체프 아리차 g1 내추럴    제이엠디커피팩토리  싱글오리진  라이트미디엄   유기농
# 3    22      1st WAVE : Supply  뉴웨이브 커피로스터스    블렌드      다크  공정무역
# 4   180           에티오피아 리무 볼렌소     베르크 로스터스  싱글오리진   미디엄다크   NaN
#
#                            컵 노트  바디감  신맛  단맛  ...  \
# 0         ['토피', ' 맥아', ' 흑설탕']    4   2   4  ...
# 1                           NaN    4   2   4  ...
# 2                           NaN    3   4   5  ...
# 3  ['다크 초콜릿', ' 마카다미아', ' 카라멜']    4   1   3  ...
# 4                ['초콜릿', ' 과일']    5   3   5  ...
#
#                                           address                     이름  \
# 0                           서울 강남구 영동대로106길 37 1층                  데일리스윗
# 1                          경기도 화성시 동탄지성로 306번길 68           브라질 세라도 디카페인
# ...

# %%
df.rename(columns={'name_x':'이름',
                        'roastery':'로스터리',
                        'introduction':'커피 소개',
                        'country':'나라',
                        'info':'로스터리 소개',
                        'address':'로스터리 주소'},
               inplace=True)

# %%
list(df.columns)
# Out:
# ['id',
#  '이름',
#  '로스터리',
#  '타입',
#  '로스팅 포인트',
#  '지속가능성',
#  '컵 노트',
#  '바디감',
#  '신맛',
#  '단맛',
#  '쓴맛',
#  '커피 소개',
#  '나라',
#  '로스터리 소개',
#  '로스터리 주소',
#  '이름',
#  '식품의 유형',
#  '제조원 및 소재지',
#  '유통기한',
#  '제조일자',
#  '내용량',
#  '보관 방법',
#  '원재료 및 함량',
#  '제품문의 관련 주소 및 전화번호']

# %%
# df.to_csv('wondoodoo.csv')

# %%
df = pd.read_csv('wondoodoo1.csv')
df.head()
# Out:
#    Unnamed: 0    id                     이름         로스터리     타입 로스팅 포인트 지속가능성  \
# 0           0    43                  데일리스윗        언더프레셔    블렌드   미디엄다크   NaN
# 1           1  3896           브라질 세라도 디카페인         운조커피   디카페인   미디엄다크   NaN
# 2           2  3458  에티오피아 예가체프 아리차 g1 내추럴    제이엠디커피팩토리  싱글오리진  라이트미디엄   유기농
# 3           3    22      1st WAVE : Supply  뉴웨이브 커피로스터스    블렌드      다크  공정무역
# 4           4   180           에티오피아 리무 볼렌소     베르크 로스터스  싱글오리진   미디엄다크   NaN
#
#                            컵 노트  바디감  신맛  ...                   이름.1  \
# 0         ['토피', ' 맥아', ' 흑설탕']    4   2  ...                  데일리스윗
# 1                           NaN    4   2  ...           브라질 세라도 디카페인
# 2                           NaN    3   4  ...  에티오피아 예가체프 아리차 g1 내추럴
# 3  ['다크 초콜릿', ' 마카다미아', ' 카라멜']    4   1  ...      1st WAVE : Supply
# 4                ['초콜릿', ' 과일']    5   3  ...           에티오피아 리무 볼렌소
#
#      식품의 유형                                       제조원 및 소재지         유통기한  \
# ...

# %%
roastery_list = list(df.로스터리.unique()) # len :: 114
roastery_list[:5]
# Out:
# ['언더프레셔', '운조커피', '제이엠디커피팩토리', '뉴웨이브 커피로스터스', '베르크 로스터스']

# %%
roastery_list.sort()

# %%
roastery_list
# Out:
# ['180커피로스터스',
#  '502 커피로스터스',
#  '55도 커피로스터스',
#  'BACS',
#  'UFO 커피로스터스',
#  '그럼블 커피로스터스',
#  '그린마일커피',
#  '글루',
#  '나무사이로',
#  '노스모크위드아웃파이어',
#  '놈코어 커피',
#  '뉴웨이브 커피로스터스',
#  '도화아파트먼트',
#  '디그리',
#  '디벨로핑룸',
#  '디카커피랩',
#  '디카프워크룸',
#  '라까프',
#  '라메르판지 비앤알',
#  '라운지엑스',
#  '랑케커피',
#  '레인디어',
#  '로스터리 카페 스테이',
#  '로컬커피 로스터스',
#  '루비아 커피',
#  '리밀커피',
#  '리버벨',
#  '리프커피',
#  '리플렉트 커피 로스터스',
#  '리플로우 커피 로스터스',
#  '링크 커피 로스터스',
#  '마그마커피',
#  '바다뷰 커피공장',
#  '베러로스팅랩',
#  '베르크 로스터스',
#  '보난자커피 코리아',
#  '보사노바 커피로스터스',
#  '브니엘 커피로스터스',
#  '블랙빈스',
#  '빈도 로스터스 커피',
#  '서가로스터리',
#  '선빌리지 커피',
#  '센터 커피',
#  '수수커피',
#  '스탠딩커피',
#  '스트레토 커피팩토리',
#  '스티머스 커피팩토리',
#  '슬러핀 커피',
#  '식물학 커피로스터스',
#  '싸인포스트커피',
#  '아드프 커피로스터스',
#  '아몰렌떼',
#  '안녕 가비 커피로스터스',
#  '알렉스더커피',
#  '애크로매틱 커피 컴퍼니',
#  '앤써커피',
#  '어나더룸',
#  '언더프레셔',
#  '엘 카페 커피로스터스',
#  '연경재',
#  '영앤도터스',
#  '오드이븐',
#  '오이르 로스터스',
#  '오프사이트',
#  '올디스트커피',
#  '올바른생각',
#  '올인커피',
#  '운조커피',
#  '원더월 커피 로스터스',
#  '웨이브온 커피',
#  '웨이즈커피',
#  '이보크',
# ...

# %%
roastery_dict = {}
i=0
for roastery in roastery_list:
    roastery_dict[roastery] = i
    i+=1
roastery_dict
# Out:
# {'180커피로스터스': 0,
#  '502 커피로스터스': 1,
#  '55도 커피로스터스': 2,
#  'BACS': 3,
#  'UFO 커피로스터스': 4,
#  '그럼블 커피로스터스': 5,
#  '그린마일커피': 6,
#  '글루': 7,
#  '나무사이로': 8,
#  '노스모크위드아웃파이어': 9,
#  '놈코어 커피': 10,
#  '뉴웨이브 커피로스터스': 11,
#  '도화아파트먼트': 12,
#  '디그리': 13,
#  '디벨로핑룸': 14,
#  '디카커피랩': 15,
#  '디카프워크룸': 16,
#  '라까프': 17,
#  '라메르판지 비앤알': 18,
#  '라운지엑스': 19,
#  '랑케커피': 20,
#  '레인디어': 21,
#  '로스터리 카페 스테이': 22,
#  '로컬커피 로스터스': 23,
#  '루비아 커피': 24,
#  '리밀커피': 25,
#  '리버벨': 26,
#  '리프커피': 27,
#  '리플렉트 커피 로스터스': 28,
#  '리플로우 커피 로스터스': 29,
#  '링크 커피 로스터스': 30,
#  '마그마커피': 31,
#  '바다뷰 커피공장': 32,
#  '베러로스팅랩': 33,
#  '베르크 로스터스': 34,
#  '보난자커피 코리아': 35,
#  '보사노바 커피로스터스': 36,
#  '브니엘 커피로스터스': 37,
#  '블랙빈스': 38,
#  '빈도 로스터스 커피': 39,
#  '서가로스터리': 40,
#  '선빌리지 커피': 41,
#  '센터 커피': 42,
#  '수수커피': 43,
#  '스탠딩커피': 44,
#  '스트레토 커피팩토리': 45,
#  '스티머스 커피팩토리': 46,
#  '슬러핀 커피': 47,
#  '식물학 커피로스터스': 48,
#  '싸인포스트커피': 49,
#  '아드프 커피로스터스': 50,
#  '아몰렌떼': 51,
#  '안녕 가비 커피로스터스': 52,
#  '알렉스더커피': 53,
#  '애크로매틱 커피 컴퍼니': 54,
# ...

# %%
for i in range(len(df)):
    df.loc[i,'로스터리ID'] = int(roastery_dict[df.loc[i,'로스터리']])
df.head()
# Out:
#    Unnamed: 0    id                     이름         로스터리     타입 로스팅 포인트 지속가능성  \
# 0           0    43                  데일리스윗        언더프레셔    블렌드   미디엄다크   NaN
# 1           1  3896           브라질 세라도 디카페인         운조커피   디카페인   미디엄다크   NaN
# 2           2  3458  에티오피아 예가체프 아리차 g1 내추럴    제이엠디커피팩토리  싱글오리진  라이트미디엄   유기농
# 3           3    22      1st WAVE : Supply  뉴웨이브 커피로스터스    블렌드      다크  공정무역
# 4           4   180           에티오피아 리무 볼렌소     베르크 로스터스  싱글오리진   미디엄다크   NaN
#
#                            컵 노트  바디감  신맛  ...    식품의 유형  \
# 0         ['토피', ' 맥아', ' 흑설탕']    4   2  ...  커피(볶은커피)
# 1                           NaN    4   2  ...        커피
# 2                           NaN    3   4  ...        커피
# 3  ['다크 초콜릿', ' 마카다미아', ' 카라멜']    4   1  ...      볶은커피
# 4                ['초콜릿', ' 과일']    5   3  ...      볶은커피
#
#                                         제조원 및 소재지         유통기한         제조일자  \
# 0                    (주)핸디엄, 경기도 여주시 세종대왕면 상동길 68  제조일로부터 12개월       상단 표기일
# ...

# %%
df = df.iloc[:,1:]
df
# Out:
#        id                     이름         로스터리     타입 로스팅 포인트 지속가능성  \
# 0      43                  데일리스윗        언더프레셔    블렌드   미디엄다크   NaN
# 1    3896           브라질 세라도 디카페인         운조커피   디카페인   미디엄다크   NaN
# 2    3458  에티오피아 예가체프 아리차 g1 내추럴    제이엠디커피팩토리  싱글오리진  라이트미디엄   유기농
# 3      22      1st WAVE : Supply  뉴웨이브 커피로스터스    블렌드      다크  공정무역
# 4     180           에티오피아 리무 볼렌소     베르크 로스터스  싱글오리진   미디엄다크   NaN
# ..    ...                    ...          ...    ...     ...   ...
# 554  3231      과테말라 우에우에테낭고 디카페인   UFO 커피로스터스   디카페인     미디엄   NaN
# 555  3526     핸디엄 밸런스 원두 아로마 5kg          핸디엄    블렌드   미디엄다크   NaN
# 556  3199            바이올렛 블렌딩 커피   링크 커피 로스터스    블렌드   미디엄다크   NaN
# 557  4839   브라질 파젠다 산타루시아 펄프드내추럴      카페소소한사치  싱글오리진  라이트미디엄   NaN
# 558  2998                  삼척블렌드  보사노바 커피로스터스    블렌드   미디엄다크   NaN
#
#                              컵 노트  바디감  신맛  단맛  ...    식품의 유형  \
# 0           ['토피', ' 맥아', ' 흑설탕']    4   2   4  ...  커피(볶은커피)
# ...

# %%
df.to_csv('wondoodoo2.csv')

# %%
with open('roasteryID.txt', 'w') as f:
    f.write(str(roastery_dict))

# %%
roastery_columns = [
 '로스터리ID',
 '로스터리',
 '로스터리 주소',
 '로스터리 소개',
]

# %%
coffee_columns = [
 'id',
 '이름',
 '로스터리ID',
 '커피 소개',
 '타입',
 '로스팅 포인트',
 '지속가능성',
 '컵 노트',
 '바디감',
 '신맛',
 '단맛',
 '쓴맛',
 '카페인',
 '나라',
 '식품의 유형',
 '제조원 및 소재지',
 '유통기한',
 '제조일자',
 '내용량',
 '보관 방법',
 '원재료 및 함량',
 '제품문의 관련 주소 및 전화번호']

# %%
roastery_df = df.loc[:,roastery_columns].drop_duplicates().reset_index(drop=True)
roastery_df.head()
# Out:
#   로스터리ID         로스터리                                         로스터리 주소  \
# 0     57        언더프레셔                           서울 강남구 영동대로106길 37 1층
# 1     67         운조커피                          경기도 화성시 동탄지성로 306번길 68
# 2     77    제이엠디커피팩토리  경기 고양시 일산동구 장대길 75-53 나동 1층 JMD Coffee Factory
# 3     11  뉴웨이브 커피로스터스                           서울특별시 양천구 오목로56길 2,1층
# 4     34     베르크 로스터스                          부산 부산진구 전포동 356-6 지하1층
#
#                                              로스터리 소개
# 0  “일상 속 특별한 휴식” 커피를 추출하는 기본 원리인 물줄기의 압력(Pressure...
# 1  커피가 나에게 준 커다란 변화를 모두와 나누고 싶습니다. 나의 이름이 붙은 커피를 ...
# 2  “JMD만의 명품 원두로 그 이상의 무한함을 창조하고자 합니다.” 커피는 이제 단지...
# 3  뉴웨이브 커피로스터스는 확고한 커피의 철학으로 우리만의 스타일로 많은 커피를 전달하...
# 4  부산에 위치한 스몰배치 스페셜티 커피 로스터리이자, 서로 다른 경험과 개성을 가진 ...

# %%
coffee_df = df.loc[:,coffee_columns].drop_duplicates().reset_index(drop=True)
coffee_df.head()
# Out:
#      id                     이름 로스터리ID  \
# 0    43                  데일리스윗     57
# 1  3896           브라질 세라도 디카페인     67
# 2  3458  에티오피아 예가체프 아리차 g1 내추럴     77
# 3    22      1st WAVE : Supply     11
# 4   180           에티오피아 리무 볼렌소     34
#
#                                                커피 소개     타입 로스팅 포인트 지속가능성  \
# 0  중남미 블렌딩으로 깊이 있는 단맛과 초콜렛티함이 조화롭게 어우러진 하우스 블렌드 입...    블렌드   미디엄다크   NaN
# 1  땅콩의 고소함과 코코아 파우더의 쌉싸름함 진득한 단맛과 클래식한 커피향  중강배전으...   디카페인   미디엄다크   NaN
# 2   장미, 베리류의 향과 감귤류의 밝은 산미 부드러운 살구의 단맛, 복합적인 꽃향기의 여운  싱글오리진  라이트미디엄   유기농
# 3                      묵직한 단맛과 카카오의 쓴맛이 입안을 가득 채웁니다.    블렌드      다크  공정무역
# 4  내추럴 프로세싱 특유의 건포도 향미가 선명히 느껴지며, 좋은 클린컵의 부드러운 산미...  싱글오리진   미디엄다크   NaN
#
#                            컵 노트  바디감  신맛  ...  카페인         나라    식품의 유형  \
# 0         ['토피', ' 맥아', ' 흑설탕']    4   2  ...    1  브라질, 과테말라  커피(볶은커피)
# 1                           NaN    4   2  ...    0        세라도        커피
# ...

# %%
coffee_df.to_csv('mysite/data/coffeeDB.csv')
roastery_df.to_csv('mysite/data/roasteryDB.csv')

# %%
import csv

# %%
roastery_csv = 'mysite/data/roasteryDB.csv'

# %%
with open(roastery_csv, newline='',encoding='utf-8') as csvfile:
    data_reader = csv.DictReader(csvfile)
    for row in data_reader:
        RoasteryID  = row['로스터리ID']
        RoasteryName  = row['로스터리']
        print(RoasteryName)
# Out:
# 언더프레셔
# 운조커피
# 제이엠디커피팩토리
# 뉴웨이브 커피로스터스
# 베르크 로스터스
# 조바티커피
# 라메르판지 비앤알
# 토치커피
# 리플로우 커피 로스터스
# 커스프 커피
# 나무사이로
# 전광수 커피
# 오프사이트
# 수수커피
# 그린마일커피
# 커피네츄럴스페셜티
# 폰트커피
# 프레이저 커피
# 180커피로스터스
# 피어 커피로스터스
# 히떼 로스터리
# 스티머스 커피팩토리
# 디그리
# 502 커피로스터스
# 카페플롬
# 어나더룸
# 루비아 커피
# 슬러핀 커피
# 랑케커피
# 디카커피랩
# 오이르 로스터스
# 펠트
# 글루
# 웨이브온 커피
# 싸인포스트커피
# 웨이즈커피
# 놈코어 커피
# 디카프워크룸
# 커피 앰비언스
# 챁챁커피
# 카페소소한사치
# 브니엘 커피로스터스
# 리버벨
# 보사노바 커피로스터스
# 스탠딩커피
# 한국커피
# 레인디어
# 안녕 가비 커피로스터스
# 크레센도 커피 로스터스
# 흐드러진커피
# 리밀커피
# 센터 커피
# 마그마커피
# 저스트로스터
# 서가로스터리
# 라운지엑스
# 애크로매틱 커피 컴퍼니
# 보난자커피 코리아
# 링크 커피 로스터스
# 이보크
# 로컬커피 로스터스
# 연경재
# 블랙빈스
# 차군커피로스터스
# 퍼블릭 커피 로스터즈
# 도화아파트먼트
# 바다뷰 커피공장
# 커피 몽타주
# 식물학 커피로스터스
# 그럼블 커피로스터스
# 올인커피
# 커피루소
# 55도 커피로스터스
# 커넥츠커피
# BACS
# 헬퍼 스튜디오
# 이수팩토리
# 커피볶는곰
# 칠복상회로스터스
# 필리그리커피
# 헤베커피
# 라까프
# 커피가이
# 크래커스 커피 로스터스
# 스트레토 커피팩토리
# 하늘에커피
# 선빌리지 커피
# 제이든 커피
# 원더월 커피 로스터스
# 알렉스더커피
# UFO 커피로스터스
# 올디스트커피
# 베러로스팅랩
# 하우트 커피컴퍼니
# 커피플라워
# 리프커피
# 이알코퍼레이션
# 영앤도터스
# 컨트리사이드
# 클라리멘토
# 컬러드 빈
# 리플렉트 커피 로스터스
# 아드프 커피로스터스
# ...

# %%
df = pd.read_csv('mysite/data/coffeeDB.csv')
len(df)
# Out:
# 559

# %%
input_string = "['우간다 로부스타 내추럴', '베트남']"

# Remove the square brackets and single quotes
output_string = input_string.replace("[", "").replace("]", "").replace("'", "")

print(output_string)
# Out:
# 우간다 로부스타 내추럴, 베트남
