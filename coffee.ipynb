# %%
import pandas as pd
df = pd.read_csv('coffeeDB.csv')
df.head(2)
# Out:
#      id            이름  로스터리ID  \
# 0    43         데일리스윗      57
# 1  3896  브라질 세라도 디카페인      67
#
#                                                커피 소개    타입 로스팅 포인트 지속가능성  \
# 0  중남미 블렌딩으로 깊이 있는 단맛과 초콜렛티함이 조화롭게 어우러진 하우스 블렌드 입...   블렌드   미디엄다크   NaN
# 1  땅콩의 고소함과 코코아 파우더의 쌉싸름함 진득한 단맛과 클래식한 커피향  중강배전으...  디카페인   미디엄다크   NaN
#
#                     컵 노트  바디감  신맛  ...         나라    식품의 유형  \
# 0  ['토피', ' 맥아', ' 흑설탕']    4   2  ...  브라질, 과테말라  커피(볶은커피)
# 1                    NaN    4   2  ...        세라도        커피
#
#                       제조원 및 소재지         유통기한        제조일자         내용량  \
# 0  (주)핸디엄, 경기도 여주시 세종대왕면 상동길 68  제조일로부터 12개월      상단 표기일  140g / 1kg
# 1        경기도 화성시 동탄지성로 306번길 68    제조일로부터 1년  주문 확인 후 제조    500g 1kg
#
#                                           보관 방법  \
# 0  직사광선을 피하고 온도, 습도가 낮으며 통풍이 잘 되는 곳에 보관하여 주십시오.
# 1       직사광선을 피하고 온도, 습도가 낮으며 통풍이 잘 되는 곳에 밀폐 보관
#
#                           원재료 및 함량   제품문의 관련 주소 및 전화번호  price
# ...

# %%
df.columns
# Out:
# Index(['id', '이름', '로스터리ID', '커피 소개', '타입', '로스팅 포인트', '지속가능성', '컵 노트', '바디감',
#        '신맛', '단맛', '쓴맛', '카페인', '나라', '식품의 유형', '제조원 및 소재지', '유통기한', '제조일자',
#        '내용량', '보관 방법', '원재료 및 함량', '제품문의 관련 주소 및 전화번호', 'price'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 23

# %%
db = pd.read_csv('../../wondoofin.csv')
db.columns
# Out:
# Index(['id', '이름', '로스터리', '타입', '로스팅 포인트', '지속가능성', '컵 노트', '바디감', '신맛', '단맛',
#        '쓴맛', '커피 소개', '나라', '로스터리 소개', '로스터리 주소', '이름.1', '식품의 유형',
#        '제조원 및 소재지', '유통기한', '제조일자', '내용량', '보관 방법', '원재료 및 함량',
#        '제품문의 관련 주소 및 전화번호', '카페인', '로스터리ID', 'price'],
#       dtype='object')

# %%
len(db.columns)
# Out:
# 27

# %%
coffee = db[['id', '이름', '로스터리ID', '커피 소개', '타입', '로스팅 포인트', '지속가능성', '컵 노트', '바디감',
       '신맛', '단맛', '쓴맛', '카페인', '나라', '식품의 유형', '제조원 및 소재지', '유통기한', '제조일자',
       '내용량', '보관 방법', '원재료 및 함량', '제품문의 관련 주소 및 전화번호', 'price']]

coffee
# Out:
#        id                     이름  로스터리ID  \
# 0      43                  데일리스윗      57
# 1    3896           브라질 세라도 디카페인      67
# 2    3458  에티오피아 예가체프 아리차 g1 내추럴      77
# 3      22      1st WAVE : Supply      11
# 4     180           에티오피아 리무 볼렌소      34
# ..    ...                    ...     ...
# 554  3231      과테말라 우에우에테낭고 디카페인       4
# 555  3526     핸디엄 밸런스 원두 아로마 5kg     109
# 556  3199            바이올렛 블렌딩 커피      30
# 557  4839   브라질 파젠다 산타루시아 펄프드내추럴      82
# 558  2998                  삼척블렌드      36
#
#                                                  커피 소개     타입 로스팅 포인트 지속가능성  \
# 0    중남미 블렌딩으로 깊이 있는 단맛과 초콜렛티함이 조화롭게 어우러진 하우스 블렌드 입...    블렌드   미디엄다크     0
# 1    땅콩의 고소함과 코코아 파우더의 쌉싸름함 진득한 단맛과 클래식한 커피향  중강배전으...   디카페인   미디엄다크     0
# 2     장미, 베리류의 향과 감귤류의 밝은 산미 부드러운 살구의 단맛, 복합적인 꽃향기의 여운  싱글오리진  라이트미디엄   유기농
# 3                        묵직한 단맛과 카카오의 쓴맛이 입안을 가득 채웁니다.    블렌드      다크  공정무역
# 4    내추럴 프로세싱 특유의 건포도 향미가 선명히 느껴지며, 좋은 클린컵의 부드러운 산미...  싱글오리진   미디엄다크     0
# ...

# %%
import numpy as np
coffee['지속가능성'] = coffee['지속가능성'].replace(0, np.nan)
# Out:
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_7948\3083001267.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coffee['지속가능성'] = coffee['지속가능성'].replace(0, np.nan)

# %%
coffee['컵 노트'] = coffee['컵 노트'].replace("['null']", np.nan)
coffee['컵 노트']
# Out:
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_7948\2254249094.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   coffee['컵 노트'] = coffee['컵 노트'].replace("['null']", np.nan)
# 0             ['토피', '맥아', '흑설탕']
# 1                             NaN
# 2                             NaN
# 3      ['다크 초콜릿', '마카다미아', '카라멜']
# 4                   ['초콜릿', '과일']
#                   ...
# 554                           NaN
# 555                           NaN
# 556                           NaN
# 557                           NaN
# 558                           NaN
# Name: 컵 노트, Length: 559, dtype: object

# %%
coffee.to_csv('coffeeDB2.csv')
